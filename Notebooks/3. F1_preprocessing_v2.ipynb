# %% [markdown]
# # F1 Win Prediction Project
# #### Alex Boardman - BrainStation

# %% [markdown]
# ### Areas to Fix
#
# - **Data Types**: Ensure that each column has the appropriate data type for the kind of data it contains. For instance, categorical data should not be typed as numeric and vice versa. If any columns are meant to be categorical or date/time but are currently recognized as 'object' or 'int64', they should be converted to the proper data type.
#
# - **Missing Data**: Your dataset contains columns with high percentages of missing values, such as 'team_development_rank_last_year' and 'status_finished_last_race'. You need to decide how to handle these, whether by imputation, deletion, or acquisition of more data if possible. For columns with a small amount of missing data, imputation might be feasible, while for those with a large percentage, it might be more appropriate to consider dropping the column.
#
# - **Duplicate Rows**: Check for any duplicate rows that might skew your analysis. If duplicates are not meaningful for your study, they should be removed.
#
# - **Uniqueness of Data**: Some columns like 'raceId' and 'driverId' are expected to have a high degree of uniqueness and serve as identifiers. Other columns that should normally have a diverse set of values but show a high degree of similarity (low uniqueness) may not be very informative and could potentially be candidates for removal.
#
# - **Data Range**: Verify the range of values in numerical columns. For instance, if 'year' has a minimum value that's in the future or a past date that's not plausible, these could be data entry errors. Check for outliers that don't make sense within the context of the data.
#
# - **Consistency**: Ensure that the data is consistent throughout the dataset. For example, if 'country' and 'nationality_of_circuit' are supposed to represent the same information, they should be consistent and possibly merged if they are redundant.
#
# - **Correctness**: For columns with 'inf' values for uniqueness, ensure they are correctly calculated. An 'inf' value might indicate a division by zero error, suggesting that the column might be entirely unique or entirely composed of a single value, each of which has different implications.
#
# - **Data Integrity**: Ensure that related columns correctly reflect relationships in the data. For example, 'number_of_pit_stops' should correlate with 'average_time_lost_in_pits' in a way that makes sense.
#
# - **Normalization/Standardization**: For machine learning purposes, you may need to standardize or normalize numerical data to ensure that the scale of the data does not unduly influence the model.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Importing Libraries and Notebook Setup

# %%
# Install libraries
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
process_df = pd.read_csv('C:/Users/Alex/OneDrive/BrainStation/Data_Science_Bootcamp/Capstone_Project/capstone-Aboard89/data/data_analysis.csv')

# %%
process_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11235 entries, 0 to 11234
# Data columns (total 36 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Index                             11235 non-null  int64
#  1   resultId                          11235 non-null  int64
#  2   raceId                            11235 non-null  int64
#  3   year                              11235 non-null  int64
#  4   race                              11235 non-null  object
#  5   country                           11235 non-null  object
#  6   nationality_of_circuit            11235 non-null  object
#  7   driverId                          11235 non-null  int64
#  8   number                            11235 non-null  int64
#  9   driver_name                       11235 non-null  object
#  10  F2_champion                       11235 non-null  int64
#  11  Former_F1_World_Champion          11235 non-null  int64
#  12  Nationality                       11235 non-null  object
#  13  home_race                         11235 non-null  int64
#  14  constructorId                     11235 non-null  int64
#  15  constructor                       11235 non-null  object
#  16  engine_manufacturer               11235 non-null  object
#  17  constructor_nationality           11235 non-null  object
#  18  number.1                          11235 non-null  int64
#  19  starting_grid_position            11235 non-null  int64
#  20  positionOrder                     11235 non-null  int64
#  21  points                            11235 non-null  float64
#  22  points_in_previous_race           10921 non-null  float64
#  23  laps                              11235 non-null  int64
#  24  laps_completed_in_previous_races  0 non-null      float64
#  25  time                              11235 non-null  object
#  26  milliseconds                      11235 non-null  object
#  27  fastestLap_ms                     11235 non-null  object
#  28  fastest_lap_from_last_race        10921 non-null  object
#  29  number_of_pit_stops               11235 non-null  int64
#  30  average_time_lost_in_pits         11235 non-null  float64
#  31  statusId                          11235 non-null  int64
#  32  status                            11235 non-null  object
#  33  major_regulation_change           11235 non-null  int64
#  34  laps_in_previous_race             10921 non-null  float64
#  35  race_win                          11235 non-null  int64
# dtypes: float64(5), int64(18), object(13)
# memory usage: 3.1+ MB

# %%
pd.set_option('display.max_columns', None)
process_df.head()
# Out:
#    Index  resultId  raceId  year                  race country  \
# 0      1      4721     240  1995  Brazilian Grand Prix  brazil
# 1      1      4724     240  1995  Brazilian Grand Prix  brazil
# 2      1      4746     240  1995  Brazilian Grand Prix  brazil
# 3      1      4745     240  1995  Brazilian Grand Prix  brazil
# 4      1      4744     240  1995  Brazilian Grand Prix  brazil
#
#   nationality_of_circuit  driverId  number            driver_name  \
# 0              Brazilian        30       1     Michael Schumacher
# 1              Brazilian        57       8          Mika Häkkinen
# 2              Brazilian        94      23      Pierluigi Martini
# 3              Brazilian        44      26          Olivier Panis
# 4              Brazilian        49      30  Heinz-Harald Frentzen
#
#    F2_champion  Former_F1_World_Champion Nationality  home_race  \
# 0            0                         1      German          0
# 1            0                         0     Finnish          0
# 2            0                         0     Italian          0
# 3            0                         0      French          0
# 4            0                         0      German          0
#
#    constructorId constructor engine_manufacturer constructor_nationality  \
# 0             22    Benetton             Renault                 Italian
# 1              1     McLaren            Mercedes                 British
# 2             18     Minardi                Ford                 Italian
# 3             27      Ligier         Mugen-Honda                  French
# 4             15      Sauber                Ford                   Swiss
#
#    number.1  starting_grid_position  positionOrder  points  \
# 0         1                       2              1    10.0
# 1         8                       7              4     3.0
# 2        23                      17             26     0.0
# 3        26                      10             25     0.0
# 4        30                      14             24     0.0
#
#    points_in_previous_race  laps  laps_completed_in_previous_races  \
# 0                      NaN    71                               NaN
# 1                      NaN    70                               NaN
# 2                      NaN     0                               NaN
# 3                      NaN     0                               NaN
# 4                      NaN    10                               NaN
#
#               time milliseconds fastestLap_ms fastest_lap_from_last_race  \
# 0  01:38:34.154000      5914154         81009                        NaN
# 1               \N           \N     Not Found                        NaN
# 2               \N           \N     Not Found                        NaN
# 3               \N           \N     Not Found                        NaN
# 4               \N           \N         84001                        NaN
#
#    number_of_pit_stops  average_time_lost_in_pits  statusId      status  \
# 0                    3                      31.83         1    Finished
# 1                    0                       0.00        11      +1 Lap
# 2                    0                       0.00         6     Gearbox
# 3                    0                       0.00         4   Collision
# 4                    0                       0.00        10  Electrical
#
#    major_regulation_change  laps_in_previous_race  race_win
# 0                        0                    NaN         1
# 1                        0                    NaN         0
# 2                        0                    NaN         0
# 3                        0                    NaN         0
# 4                        0                    NaN         0

# %%
process_df['new_index'] = process_df['Index'] + process_df['driverId']

# %% [markdown]
# The above is create a new index column, so that I can track who the model think is going to win races when we get to the prediction stage.
#
# I then want to make this the new index of my dataframe

# %%
process_df = process_df.set_index('new_index')

# %%
process_df.head()
# Out:
#            Index  resultId  raceId  year                  race country  \
# new_index
# 31             1      4721     240  1995  Brazilian Grand Prix  brazil
# 58             1      4724     240  1995  Brazilian Grand Prix  brazil
# 95             1      4746     240  1995  Brazilian Grand Prix  brazil
# 45             1      4745     240  1995  Brazilian Grand Prix  brazil
# 50             1      4744     240  1995  Brazilian Grand Prix  brazil
#
#           nationality_of_circuit  driverId  number            driver_name  \
# new_index
# 31                     Brazilian        30       1     Michael Schumacher
# 58                     Brazilian        57       8          Mika Häkkinen
# 95                     Brazilian        94      23      Pierluigi Martini
# 45                     Brazilian        44      26          Olivier Panis
# 50                     Brazilian        49      30  Heinz-Harald Frentzen
#
#            F2_champion  Former_F1_World_Champion Nationality  home_race  \
# new_index
# 31                   0                         1      German          0
# 58                   0                         0     Finnish          0
# 95                   0                         0     Italian          0
# 45                   0                         0      French          0
# 50                   0                         0      German          0
#
#            constructorId constructor engine_manufacturer  \
# new_index
# 31                    22    Benetton             Renault
# 58                     1     McLaren            Mercedes
# 95                    18     Minardi                Ford
# 45                    27      Ligier         Mugen-Honda
# 50                    15      Sauber                Ford
#
#           constructor_nationality  number.1  starting_grid_position  \
# new_index
# 31                        Italian         1                       2
# 58                        British         8                       7
# 95                        Italian        23                      17
# 45                         French        26                      10
# 50                          Swiss        30                      14
#
#            positionOrder  points  points_in_previous_race  laps  \
# new_index
# 31                     1    10.0                      NaN    71
# 58                     4     3.0                      NaN    70
# 95                    26     0.0                      NaN     0
# 45                    25     0.0                      NaN     0
# 50                    24     0.0                      NaN    10
#
#            laps_completed_in_previous_races             time milliseconds  \
# new_index
# 31                                      NaN  01:38:34.154000      5914154
# 58                                      NaN               \N           \N
# 95                                      NaN               \N           \N
# 45                                      NaN               \N           \N
# 50                                      NaN               \N           \N
#
#           fastestLap_ms fastest_lap_from_last_race  number_of_pit_stops  \
# new_index
# 31                81009                        NaN                    3
# 58            Not Found                        NaN                    0
# 95            Not Found                        NaN                    0
# 45            Not Found                        NaN                    0
# 50                84001                        NaN                    0
#
#            average_time_lost_in_pits  statusId      status  \
# new_index
# 31                             31.83         1    Finished
# 58                              0.00        11      +1 Lap
# 95                              0.00         6     Gearbox
# 45                              0.00         4   Collision
# 50                              0.00        10  Electrical
#
#            major_regulation_change  laps_in_previous_race  race_win
# new_index
# 31                               0                    NaN         1
# 58                               0                    NaN         0
# 95                               0                    NaN         0
# 45                               0                    NaN         0
# 50                               0                    NaN         0

# %% [markdown]
# That looks like it has worked correctly

# %% [markdown]
# ### Rename Columns

# %%
process_df = process_df.rename(columns={'Index': 'race_index'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 process_df = process_df.rename(columns={'Index': 'race_index'})
#
# NameError: name 'process_df' is not defined

# %% [markdown]
# ### Drop Redundant Columns

# %%
# Define the columns to be dropped
cols_to_drop = ["Index",
    "raceId", "resultId", "race", "country",
    "nationality_of_circuit", "driver_name", "driverId", "number",
    "fastestLap_ms", "status", "constructor", "positionOrder", "number.1",
    "laps", "major_regulation_change", "time", "milliseconds"
]

# Verify that the columns exist in the DataFrame before dropping them
existing_cols_to_drop = [col for col in cols_to_drop if col in process_df.columns]

# Drop the verified columns from the DataFrame
process_df.drop(columns=existing_cols_to_drop, axis=1, inplace=True)

# %%
process_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11235 entries, 31 to 1384
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   year                              11235 non-null  int64
#  1   F2_champion                       11235 non-null  int64
#  2   Former_F1_World_Champion          11235 non-null  int64
#  3   Nationality                       11235 non-null  object
#  4   home_race                         11235 non-null  int64
#  5   constructorId                     11235 non-null  int64
#  6   engine_manufacturer               11235 non-null  object
#  7   constructor_nationality           11235 non-null  object
#  8   starting_grid_position            11235 non-null  int64
#  9   points                            11235 non-null  float64
#  10  points_in_previous_race           10921 non-null  float64
#  11  laps_completed_in_previous_races  0 non-null      float64
#  12  fastest_lap_from_last_race        10921 non-null  object
#  13  number_of_pit_stops               11235 non-null  int64
#  14  average_time_lost_in_pits         11235 non-null  float64
#  15  statusId                          11235 non-null  int64
#  16  laps_in_previous_race             10921 non-null  float64
#  17  race_win                          11235 non-null  int64
# dtypes: float64(5), int64(9), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# ### Changing Data Types

# %%
# # Convert columns to the right data types
# df[col] = df[col].astype('string')
# df[col] = df[col].astype('int')
# df[col] = pd.to_datetime(df[col], infer_datetime_format=True)

# # Convert to categorical datatype
# col_cat = ptypes.CategoricalDtype(categories=['A', 'B', 'C'], ordered=True)
# df['col_cat'] = df['col_cat'].astype(col_cat)

# %%
# # Verify conversion
# assert ptypes.is_string_dtype(df[col])
# assert ptypes.is_numeric_dtype(df[col])
# cols_to_check = []
# assert all(ptypes.is_datetime64_any_dtype(df[col]) for col in cols_to_check)

# %% [markdown]
# ### Dropping Duplicates

# %%
# # Drop entirely duplicated rows
# df.drop_duplicates(inplace=True, ignore_index=True)

# %%
# # Verify rows dropped
# assert df.duplicated().sum()==0

# %% [markdown]
# ### Handling Unreasonable Data Ranges

# %%
# # Drop affected rows
# df = df.loc[~((df['A'] == 0) | (df['B'] > 100))].reset_index()

# %%
# # Verify rows dropped
# len(df)

# %% [markdown]
# ### Feature Engineering / Transformation

# %% [markdown]
# #### constructor_points_at_stage_of_season

# %%
#constuctor_points_sum_df.info()

# %%
constructor_points_sum_df = process_df.copy()

# %%
# First, ensure 'race_index', 'year', and 'constructorId' are sorted in the order we want to process them
constructor_points_sum_df = constructor_points_sum_df.sort_values(by=['year', 'race_index', 'constructorId'])

# Initialize a new column for corrected constructorId points
constructor_points_sum_df['corrected_constructorId_points'] = 0

# Use a temporary DataFrame to assist with the cumulative sum calculation
temp_df = constructor_points_sum_df.groupby(['year', 'race_index', 'constructorId'])['points'].sum().groupby(level=[0, 2]).cumsum().reset_index()

# Merge this temporary DataFrame back to the original sorted DataFrame
# This step ensures each driver for the constructorId at that race_index sees the summed points on the constructorId level
df_merged = pd.merge(constructor_points_sum_df, temp_df, on=['year', 'race_index', 'constructorId'], how='left')

# The merged DataFrame now has an additional column with the cumulative points which needs to be renamed and checked
df_merged = df_merged.rename(columns={'points_y': 'constructorId_points_at_stage_of_season', 'points_x': 'points'})

# Drop the previously incorrectly calculated column
df_merged.drop(columns=['corrected_constructorId_points'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1480\2508636433.py in ?()
# ----> 2 # First, ensure 'race_index', 'year', and 'constructorId' are sorted in the order we want to process them
#       3 constructor_points_sum_df = constructor_points_sum_df.sort_values(by=['year', 'race_index', 'constructorId'])
#       4
#       5 # Initialize a new column for corrected constructorId points
#
# c:\Users\Alex\anaconda3\envs\capstone\lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6736                 f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    6737                 f" != length of by ({len(by)})"
#    6738             )
#    6739         if len(by) > 1:
# -> 6740             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6741
#    6742             # need to rewrap columns in Series to apply key function
#    6743             if key is not None:
#
# c:\Users\Alex\anaconda3\envs\capstone\lib\site-packages\pandas\core\frame.py in ?(.0)
# -> 6740     def sort_values(
#    6741         self,
#    6742         by: IndexLabel,
#    6743         *,
#
# c:\Users\Alex\anaconda3\envs\capstone\lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1774             values = self.xs(key, axis=other_axes[0])._values
#    1775         elif self._is_level_reference(key, axis=axis):
#    1776             values = self.axes[axis].get_level_values(key)._values
#    1777         else:
# -> 1778             raise KeyError(key)
#    1779
#    1780         # Check for duplicates
#    1781         if values.ndim > 1:
#
# KeyError: 'race_index'

# %%
# Check the first few rows to ensure the new column has been correctly calculated
df_merged[['race_index', 'driver_name', 'year', 'constructorId', 'points', 'constructorId_points_at_stage_of_season']].head(50)
# Out:
#     race_index             driver_name  year  constructorId  points  \
# 0            1           Mika Häkkinen  1995              1     3.0
# 1            1           Mark Blundell  1995              1     1.0
# 2            1              Damon Hill  1995              3     0.0
# 3            1         David Coulthard  1995              3     6.0
# 4            1          Gerhard Berger  1995              6     4.0
# 5            1              Jean Alesi  1995              6     2.0
# 6            1   Heinz-Harald Frentzen  1995             15     0.0
# 7            1         Karl Wendlinger  1995             15     0.0
# 8            1            Eddie Irvine  1995             17     0.0
# 9            1      Rubens Barrichello  1995             17     0.0
# 10           1       Pierluigi Martini  1995             18     0.0
# 11           1             Luca Badoer  1995             18     0.0
# 12           1      Michael Schumacher  1995             22    10.0
# 13           1          Johnny Herbert  1995             22     0.0
# 14           1           Ukyo Katayama  1995             25     0.0
# 15           1               Mika Salo  1995             25     0.0
# 16           1           Olivier Panis  1995             27     0.0
# 17           1            Aguri Suzuki  1995             27     0.0
# 18           1          Roberto Moreno  1995             28     0.0
# 19           1             Pedro Diniz  1995             28     0.0
# 20           1       Gianni Morbidelli  1995             29     0.0
# 21           1              Taki Inoue  1995             29     0.0
# 22           1         Bertrand Gachot  1995             30     0.0
# 23           1       Andrea Montermini  1995             30     0.0
# 24           1  Domenico Schiattarella  1995             31     0.0
# 25           1          Jos Verstappen  1995             31     0.0
# 26           2           Mark Blundell  1995              1     0.0
# 27           2           Mika Häkkinen  1995              1     0.0
# 28           2         David Coulthard  1995              3     0.0
# 29           2              Damon Hill  1995              3    10.0
# 30           2              Jean Alesi  1995              6     6.0
# 31           2          Gerhard Berger  1995              6     1.0
# 32           2         Karl Wendlinger  1995             15     0.0
# 33           2   Heinz-Harald Frentzen  1995             15     2.0
# 34           2      Rubens Barrichello  1995             17     0.0
# 35           2            Eddie Irvine  1995             17     0.0
# 36           2             Luca Badoer  1995             18     0.0
# 37           2       Pierluigi Martini  1995             18     0.0
# 38           2      Michael Schumacher  1995             22     4.0
# 39           2          Johnny Herbert  1995             22     3.0
# 40           2               Mika Salo  1995             25     0.0
# 41           2           Ukyo Katayama  1995             25     0.0
# 42           2            Aguri Suzuki  1995             27     0.0
# 43           2           Olivier Panis  1995             27     0.0
# 44           2             Pedro Diniz  1995             28     0.0
# 45           2          Roberto Moreno  1995             28     0.0
# 46           2              Taki Inoue  1995             29     0.0
# 47           2       Gianni Morbidelli  1995             29     0.0
# 48           2         Bertrand Gachot  1995             30     0.0
# 49           2       Andrea Montermini  1995             30     0.0
#
#     constructorId_points_at_stage_of_season
# 0                                       4.0
# 1                                       4.0
# 2                                       6.0
# 3                                       6.0
# 4                                       6.0
# 5                                       6.0
# 6                                       0.0
# 7                                       0.0
# 8                                       0.0
# 9                                       0.0
# 10                                      0.0
# 11                                      0.0
# 12                                     10.0
# 13                                     10.0
# 14                                      0.0
# 15                                      0.0
# 16                                      0.0
# 17                                      0.0
# 18                                      0.0
# 19                                      0.0
# 20                                      0.0
# 21                                      0.0
# 22                                      0.0
# 23                                      0.0
# 24                                      0.0
# 25                                      0.0
# 26                                      4.0
# 27                                      4.0
# 28                                     16.0
# 29                                     16.0
# 30                                     13.0
# 31                                     13.0
# 32                                      2.0
# 33                                      2.0
# 34                                      0.0
# 35                                      0.0
# 36                                      0.0
# 37                                      0.0
# 38                                     17.0
# 39                                     17.0
# 40                                      0.0
# 41                                      0.0
# 42                                      0.0
# 43                                      0.0
# 44                                      0.0
# 45                                      0.0
# 46                                      0.0
# 47                                      0.0
# 48                                      0.0
# 49                                      0.0

# %%
# Check the first few rows to ensure the new column has been correctly calculated
df_merged[['race_index', 'driver_name', 'year', 'constructorId', 'points', 'constructorId_points_at_stage_of_season']].tail(50)
# Out:
#        race_index       driver_name  year  constructorId  points  \
# 11185         525      Lance Stroll  2023            117     0.0
# 11186         525   Fernando Alonso  2023            117     6.0
# 11187         525    George Russell  2023            131    10.0
# 11188         525    Lewis Hamilton  2023            131    15.0
# 11189         525   Kevin Magnussen  2023            210     0.0
# 11190         525   Nico Hülkenberg  2023            210     0.0
# 11191         525     Nyck de Vries  2023            213     0.0
# 11192         525      Yuki Tsunoda  2023            213     0.0
# 11193         525      Pierre Gasly  2023            214     0.0
# 11194         525      Esteban Ocon  2023            214     0.0
# 11195         526     Oscar Piastri  2023              1    10.0
# 11196         526      Lando Norris  2023              1    18.0
# 11197         526    Logan Sargeant  2023              3     0.0
# 11198         526   Alexander Albon  2023              3     0.0
# 11199         526      Carlos Sainz  2023              6     4.0
# 11200         526   Charles Leclerc  2023              6     6.0
# 11201         526    Max Verstappen  2023              9    26.0
# 11202         526      Sergio Pérez  2023              9    15.0
# 11203         526   Valtteri Bottas  2023             51     0.0
# 11204         526       Guanyu Zhou  2023             51     0.0
# 11205         526      Lance Stroll  2023            117     1.0
# 11206         526   Fernando Alonso  2023            117     2.0
# 11207         526    George Russell  2023            131     8.0
# 11208         526    Lewis Hamilton  2023            131    12.0
# 11209         526   Kevin Magnussen  2023            210     0.0
# 11210         526   Nico Hülkenberg  2023            210     0.0
# 11211         526  Daniel Ricciardo  2023            213     0.0
# 11212         526      Yuki Tsunoda  2023            213     0.0
# 11213         526      Pierre Gasly  2023            214     0.0
# 11214         526      Esteban Ocon  2023            214     0.0
# 11215         527      Lando Norris  2023              1     6.0
# 11216         527     Oscar Piastri  2023              1     0.0
# 11217         527    Logan Sargeant  2023              3     0.0
# 11218         527   Alexander Albon  2023              3     0.0
# 11219         527   Charles Leclerc  2023              6    15.0
# 11220         527      Carlos Sainz  2023              6     0.0
# 11221         527    Max Verstappen  2023              9    25.0
# 11222         527      Sergio Pérez  2023              9    18.0
# 11223         527   Valtteri Bottas  2023             51     0.0
# 11224         527       Guanyu Zhou  2023             51     0.0
# 11225         527      Lance Stroll  2023            117     2.0
# 11226         527   Fernando Alonso  2023            117    10.0
# 11227         527    Lewis Hamilton  2023            131    13.0
# 11228         527    George Russell  2023            131     8.0
# 11229         527   Kevin Magnussen  2023            210     0.0
# 11230         527   Nico Hülkenberg  2023            210     0.0
# 11231         527  Daniel Ricciardo  2023            213     0.0
# 11232         527      Yuki Tsunoda  2023            213     1.0
# 11233         527      Pierre Gasly  2023            214     0.0
# 11234         527      Esteban Ocon  2023            214     4.0
#
#        constructorId_points_at_stage_of_season
# 11185                                    168.0
# 11186                                    168.0
# 11187                                    195.0
# 11188                                    195.0
# 11189                                      8.0
# 11190                                      8.0
# 11191                                      2.0
# 11192                                      2.0
# 11193                                     45.0
# 11194                                     45.0
# 11195                                     87.0
# 11196                                     87.0
# 11197                                     11.0
# 11198                                     11.0
# 11199                                    150.0
# 11200                                    150.0
# 11201                                    423.0
# 11202                                    423.0
# 11203                                      9.0
# 11204                                      9.0
# 11205                                    171.0
# 11206                                    171.0
# 11207                                    215.0
# 11208                                    215.0
# 11209                                      8.0
# 11210                                      8.0
# 11211                                      2.0
# 11212                                      2.0
# 11213                                     45.0
# 11214                                     45.0
# 11215                                     93.0
# 11216                                     93.0
# 11217                                     11.0
# 11218                                     11.0
# 11219                                    165.0
# 11220                                    165.0
# 11221                                    466.0
# 11222                                    466.0
# 11223                                      9.0
# 11224                                      9.0
# 11225                                    183.0
# 11226                                    183.0
# 11227                                    236.0
# 11228                                    236.0
# 11229                                      8.0
# 11230                                      8.0
# 11231                                      3.0
# 11232                                      3.0
# 11233                                     49.0
# 11234                                     49.0

# %% [markdown]
# That seems to have worked - now we have a column that has the cumulative points for the constructor at this stage of the season for each driver.

# %% [markdown]
# #### driver_points_at_stage_of_season

# %%
driver_points_sum_df = df_merged.copy()

# %%
# Use a temporary DataFrame to assist with the cumulative sum calculation for drivers
temp_driver_df = driver_points_sum_df.groupby(['year', 'race_index', 'driver_name'])['points'].sum().groupby(level=[0, 2]).cumsum().reset_index()

# Merge this temporary DataFrame back to the original DataFrame
# This step ensures each driver sees the summed points at that stage of the season
df_merged_with_driver_points = pd.merge(driver_points_sum_df, temp_driver_df, on=['year', 'race_index', 'driver_name'], how='left')

# The merged DataFrame now has an additional column with the cumulative points which needs to be renamed and checked
df_merged_with_driver_points = df_merged_with_driver_points.rename(columns={'points_y': 'driver_points_at_stage_of_season', 'points_x': 'points'})

# %%
# Check the first few rows to ensure the new column has been correctly calculated
df_merged_with_driver_points[['race_index', 'year', 'driver_name', 'points', 'driver_points_at_stage_of_season']].head(50)
# Out:
#     race_index  year             driver_name  points  \
# 0            1  1995           Mika Häkkinen     3.0
# 1            1  1995           Mark Blundell     1.0
# 2            1  1995              Damon Hill     0.0
# 3            1  1995         David Coulthard     6.0
# 4            1  1995          Gerhard Berger     4.0
# 5            1  1995              Jean Alesi     2.0
# 6            1  1995   Heinz-Harald Frentzen     0.0
# 7            1  1995         Karl Wendlinger     0.0
# 8            1  1995            Eddie Irvine     0.0
# 9            1  1995      Rubens Barrichello     0.0
# 10           1  1995       Pierluigi Martini     0.0
# 11           1  1995             Luca Badoer     0.0
# 12           1  1995      Michael Schumacher    10.0
# 13           1  1995          Johnny Herbert     0.0
# 14           1  1995           Ukyo Katayama     0.0
# 15           1  1995               Mika Salo     0.0
# 16           1  1995           Olivier Panis     0.0
# 17           1  1995            Aguri Suzuki     0.0
# 18           1  1995          Roberto Moreno     0.0
# 19           1  1995             Pedro Diniz     0.0
# 20           1  1995       Gianni Morbidelli     0.0
# 21           1  1995              Taki Inoue     0.0
# 22           1  1995         Bertrand Gachot     0.0
# 23           1  1995       Andrea Montermini     0.0
# 24           1  1995  Domenico Schiattarella     0.0
# 25           1  1995          Jos Verstappen     0.0
# 26           2  1995           Mark Blundell     0.0
# 27           2  1995           Mika Häkkinen     0.0
# 28           2  1995         David Coulthard     0.0
# 29           2  1995              Damon Hill    10.0
# 30           2  1995              Jean Alesi     6.0
# 31           2  1995          Gerhard Berger     1.0
# 32           2  1995         Karl Wendlinger     0.0
# 33           2  1995   Heinz-Harald Frentzen     2.0
# 34           2  1995      Rubens Barrichello     0.0
# 35           2  1995            Eddie Irvine     0.0
# 36           2  1995             Luca Badoer     0.0
# 37           2  1995       Pierluigi Martini     0.0
# 38           2  1995      Michael Schumacher     4.0
# 39           2  1995          Johnny Herbert     3.0
# 40           2  1995               Mika Salo     0.0
# 41           2  1995           Ukyo Katayama     0.0
# 42           2  1995            Aguri Suzuki     0.0
# 43           2  1995           Olivier Panis     0.0
# 44           2  1995             Pedro Diniz     0.0
# 45           2  1995          Roberto Moreno     0.0
# 46           2  1995              Taki Inoue     0.0
# 47           2  1995       Gianni Morbidelli     0.0
# 48           2  1995         Bertrand Gachot     0.0
# 49           2  1995       Andrea Montermini     0.0
#
#     driver_points_at_stage_of_season
# 0                                3.0
# 1                                1.0
# 2                                0.0
# 3                                6.0
# 4                                4.0
# 5                                2.0
# 6                                0.0
# 7                                0.0
# 8                                0.0
# 9                                0.0
# 10                               0.0
# 11                               0.0
# 12                              10.0
# 13                               0.0
# 14                               0.0
# 15                               0.0
# 16                               0.0
# 17                               0.0
# 18                               0.0
# 19                               0.0
# 20                               0.0
# 21                               0.0
# 22                               0.0
# 23                               0.0
# 24                               0.0
# 25                               0.0
# 26                               1.0
# 27                               3.0
# 28                               6.0
# 29                              10.0
# 30                               8.0
# 31                               5.0
# 32                               0.0
# 33                               2.0
# 34                               0.0
# 35                               0.0
# 36                               0.0
# 37                               0.0
# 38                              14.0
# 39                               3.0
# 40                               0.0
# 41                               0.0
# 42                               0.0
# 43                               0.0
# 44                               0.0
# 45                               0.0
# 46                               0.0
# 47                               0.0
# 48                               0.0
# 49                               0.0

# %%
# Check the first few rows to ensure the new column has been correctly calculated
df_merged_with_driver_points[['race_index', 'year', 'driver_name', 'points', 'driver_points_at_stage_of_season']].tail(50)
# Out:
#        race_index  year       driver_name  points  \
# 11185         525  2023      Lance Stroll     0.0
# 11186         525  2023   Fernando Alonso     6.0
# 11187         525  2023    George Russell    10.0
# 11188         525  2023    Lewis Hamilton    15.0
# 11189         525  2023   Kevin Magnussen     0.0
# 11190         525  2023   Nico Hülkenberg     0.0
# 11191         525  2023     Nyck de Vries     0.0
# 11192         525  2023      Yuki Tsunoda     0.0
# 11193         525  2023      Pierre Gasly     0.0
# 11194         525  2023      Esteban Ocon     0.0
# 11195         526  2023     Oscar Piastri    10.0
# 11196         526  2023      Lando Norris    18.0
# 11197         526  2023    Logan Sargeant     0.0
# 11198         526  2023   Alexander Albon     0.0
# 11199         526  2023      Carlos Sainz     4.0
# 11200         526  2023   Charles Leclerc     6.0
# 11201         526  2023    Max Verstappen    26.0
# 11202         526  2023      Sergio Pérez    15.0
# 11203         526  2023   Valtteri Bottas     0.0
# 11204         526  2023       Guanyu Zhou     0.0
# 11205         526  2023      Lance Stroll     1.0
# 11206         526  2023   Fernando Alonso     2.0
# 11207         526  2023    George Russell     8.0
# 11208         526  2023    Lewis Hamilton    12.0
# 11209         526  2023   Kevin Magnussen     0.0
# 11210         526  2023   Nico Hülkenberg     0.0
# 11211         526  2023  Daniel Ricciardo     0.0
# 11212         526  2023      Yuki Tsunoda     0.0
# 11213         526  2023      Pierre Gasly     0.0
# 11214         526  2023      Esteban Ocon     0.0
# 11215         527  2023      Lando Norris     6.0
# 11216         527  2023     Oscar Piastri     0.0
# 11217         527  2023    Logan Sargeant     0.0
# 11218         527  2023   Alexander Albon     0.0
# 11219         527  2023   Charles Leclerc    15.0
# 11220         527  2023      Carlos Sainz     0.0
# 11221         527  2023    Max Verstappen    25.0
# 11222         527  2023      Sergio Pérez    18.0
# 11223         527  2023   Valtteri Bottas     0.0
# 11224         527  2023       Guanyu Zhou     0.0
# 11225         527  2023      Lance Stroll     2.0
# 11226         527  2023   Fernando Alonso    10.0
# 11227         527  2023    Lewis Hamilton    13.0
# 11228         527  2023    George Russell     8.0
# 11229         527  2023   Kevin Magnussen     0.0
# 11230         527  2023   Nico Hülkenberg     0.0
# 11231         527  2023  Daniel Ricciardo     0.0
# 11232         527  2023      Yuki Tsunoda     1.0
# 11233         527  2023      Pierre Gasly     0.0
# 11234         527  2023      Esteban Ocon     4.0
#
#        driver_points_at_stage_of_season
# 11185                              38.0
# 11186                             130.0
# 11187                              76.0
# 11188                             119.0
# 11189                               2.0
# 11190                               6.0
# 11191                               0.0
# 11192                               2.0
# 11193                              16.0
# 11194                              29.0
# 11195                              27.0
# 11196                              60.0
# 11197                               0.0
# 11198                              11.0
# 11199                              77.0
# 11200                              73.0
# 11201                             267.0
# 11202                             156.0
# 11203                               5.0
# 11204                               4.0
# 11205                              39.0
# 11206                             132.0
# 11207                              84.0
# 11208                             131.0
# 11209                               2.0
# 11210                               6.0
# 11211                               0.0
# 11212                               2.0
# 11213                              16.0
# 11214                              29.0
# 11215                              66.0
# 11216                              27.0
# 11217                               0.0
# 11218                              11.0
# 11219                              88.0
# 11220                              77.0
# 11221                             292.0
# 11222                             174.0
# 11223                               5.0
# 11224                               4.0
# 11225                              41.0
# 11226                             142.0
# 11227                             144.0
# 11228                              92.0
# 11229                               2.0
# 11230                               6.0
# 11231                               0.0
# 11232                               3.0
# 11233                              16.0
# 11234                              33.0

# %% [markdown]
# That seems to have worked - now we have a column that has the cumulative points for the driver at this stage of the season for each driver.

# %% [markdown]
# ### Other Feature Engineering Ideas

# %% [markdown]
# 1) team_development_rank_last_year,
# 2) statusId_finished_last_race
# 3) team_rank_first_race_after_major_regulation_change

# %%
df_merged_with_driver_points.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11235 entries, 0 to 11234
# Data columns (total 22 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   race_index                               11235 non-null  int64
#  1   year                                     11235 non-null  int64
#  2   driver_name                              11235 non-null  object
#  3   F2_champion                              11235 non-null  int64
#  4   Former_F1_World_Champion                 11235 non-null  int64
#  5   Nationality                              11235 non-null  object
#  6   home_race                                11235 non-null  int64
#  7   constructorId                            11235 non-null  int64
#  8   engine_manufacturer                      11235 non-null  object
#  9   constructor_nationality                  11235 non-null  object
#  10  starting_grid_position                   11235 non-null  int64
#  11  points                                   11235 non-null  float64
#  12  points_in_previous_race                  10921 non-null  float64
#  13  laps_completed_in_previous_races         0 non-null      float64
#  14  fastest_lap_from_last_race               10921 non-null  object
#  15  number_of_pit_stops                      11235 non-null  int64
#  16  average_time_lost_in_pits                11235 non-null  float64
#  17  statusId                                 11235 non-null  int64
#  18  laps_in_previous_race                    10921 non-null  float64
#  19  race_win                                 11235 non-null  int64
#  20  constructorId_points_at_stage_of_season  11235 non-null  float64
#  21  driver_points_at_stage_of_season         11235 non-null  float64
# dtypes: float64(7), int64(10), object(5)
# memory usage: 1.9+ MB

# %%
df_merged_with_driver_points.head().T
# Out:
#                                                      0              1  \
# race_index                                           1              1
# year                                              1995           1995
# driver_name                              Mika Häkkinen  Mark Blundell
# F2_champion                                          0              0
# Former_F1_World_Champion                             0              0
# Nationality                                    Finnish        British
# home_race                                            0              0
# constructorId                                        1              1
# engine_manufacturer                           Mercedes       Mercedes
# constructor_nationality                        British        British
# starting_grid_position                               7              9
# points                                             3.0            1.0
# points_in_previous_race                            NaN            NaN
# laps_completed_in_previous_races                   NaN            NaN
# fastest_lap_from_last_race                         NaN            NaN
# number_of_pit_stops                                  0              2
# average_time_lost_in_pits                          0.0          37.53
# statusId                                            11             11
# laps_in_previous_race                              NaN            NaN
# race_win                                             0              0
# constructorId_points_at_stage_of_season            4.0            4.0
# driver_points_at_stage_of_season                   3.0            1.0
#
#                                                   2                3  \
# race_index                                        1                1
# year                                           1995             1995
# driver_name                              Damon Hill  David Coulthard
# F2_champion                                       0                0
# Former_F1_World_Champion                          1                0
# Nationality                                 British          British
# home_race                                         0                0
# constructorId                                     3                3
# engine_manufacturer                         Renault          Renault
# constructor_nationality                     British          British
# starting_grid_position                            1                3
# points                                          0.0              6.0
# points_in_previous_race                         NaN              NaN
# laps_completed_in_previous_races                NaN              NaN
# fastest_lap_from_last_race                      NaN              NaN
# number_of_pit_stops                               1                1
# average_time_lost_in_pits                     34.32            34.17
# statusId                                          6                1
# laps_in_previous_race                           NaN              NaN
# race_win                                          0                0
# constructorId_points_at_stage_of_season         6.0              6.0
# driver_points_at_stage_of_season                0.0              6.0
#
#                                                       4
# race_index                                            1
# year                                               1995
# driver_name                              Gerhard Berger
# F2_champion                                           0
# Former_F1_World_Champion                              0
# Nationality                                    Austrian
# home_race                                             0
# constructorId                                         6
# engine_manufacturer                             Ferrari
# constructor_nationality                         Italian
# starting_grid_position                                5
# points                                              4.0
# points_in_previous_race                             NaN
# laps_completed_in_previous_races                    NaN
# fastest_lap_from_last_race                          NaN
# number_of_pit_stops                                   2
# average_time_lost_in_pits                         38.94
# statusId                                             11
# laps_in_previous_race                               NaN
# race_win                                              0
# constructorId_points_at_stage_of_season             6.0
# driver_points_at_stage_of_season                    4.0

# %%
# Define the columns to be dropped
cols_to_drop = [
    "driver_name", "resultId", "number_of_pit_stops", "average_time_lost_in_pits",
    "statusId", "laps_completed_in_previous_races", "points"
]

# %% [markdown]
# NB - laps_completed_in_previous_races, I have dropped for the time being. It was full of null values. I will run the first models and use thenm as benchmarks and then see if I can improve the scores.
# The other columns I didn't think were helpful for the following reasons
# - `number_of_pit_stops` & `average_time_lost_in_pits` - as we are trying to predict the race winner before the race, this information isn't very helpful at this stage. It may be interesting to see how last year's pit strategy at a particular race will impact next year's race, but it's not so helpful in it's current form.
# - `points` - this isn't helpful, as we want to predict forwards and this is captured from `constructorId_points_at_stage_of_season` & `driver_points_at_stage_of_season` columns

# %%
# Verify that the columns exist in the DataFrame before dropping them
existing_cols_to_drop = [col for col in cols_to_drop if col in df_merged_with_driver_points.columns]

# Drop the verified columns from the DataFrame
df_merged_with_driver_points.drop(columns=existing_cols_to_drop, axis=1, inplace=True)

# %%
df_merged_with_driver_points.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11235 entries, 0 to 11234
# Data columns (total 16 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   race_index                               11235 non-null  int64
#  1   year                                     11235 non-null  int64
#  2   F2_champion                              11235 non-null  int64
#  3   Former_F1_World_Champion                 11235 non-null  int64
#  4   Nationality                              11235 non-null  object
#  5   home_race                                11235 non-null  int64
#  6   constructorId                            11235 non-null  int64
#  7   engine_manufacturer                      11235 non-null  object
#  8   constructor_nationality                  11235 non-null  object
#  9   starting_grid_position                   11235 non-null  int64
#  10  points_in_previous_race                  10921 non-null  float64
#  11  fastest_lap_from_last_race               10921 non-null  object
#  12  laps_in_previous_race                    10921 non-null  float64
#  13  race_win                                 11235 non-null  int64
#  14  constructorId_points_at_stage_of_season  11235 non-null  float64
#  15  driver_points_at_stage_of_season         11235 non-null  float64
# dtypes: float64(4), int64(8), object(4)
# memory usage: 1.4+ MB

# %%
df_merged_with_driver_points.to_csv('merged_with_driver_points.csv', index=False)

# %% [markdown]
# ### One Hot Encoding

# %%
# Perform one-hot encoding on the specified columns
df_with_dummies = pd.get_dummies(df_merged_with_driver_points, columns=['engine_manufacturer', 'constructor_nationality', 'Nationality'])

# Now df_with_dummies contains the original data along with the one-hot encoded columns

# %%
df_with_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11235 entries, 0 to 11234
# Data columns (total 82 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   race_index                               11235 non-null  int64
#  1   year                                     11235 non-null  int64
#  2   F2_champion                              11235 non-null  int64
#  3   Former_F1_World_Champion                 11235 non-null  int64
#  4   home_race                                11235 non-null  int64
#  5   constructorId                            11235 non-null  int64
#  6   starting_grid_position                   11235 non-null  int64
#  7   points_in_previous_race                  10921 non-null  float64
#  8   fastest_lap_from_last_race               10921 non-null  object
#  9   laps_in_previous_race                    10921 non-null  float64
#  10  race_win                                 11235 non-null  int64
#  11  constructorId_points_at_stage_of_season  11235 non-null  float64
#  12  driver_points_at_stage_of_season         11235 non-null  float64
#  13  engine_manufacturer_Acer                 11235 non-null  bool
#  14  engine_manufacturer_Arrows               11235 non-null  bool
#  15  engine_manufacturer_Asiatech             11235 non-null  bool
#  16  engine_manufacturer_BMW                  11235 non-null  bool
#  17  engine_manufacturer_Cosworth             11235 non-null  bool
#  18  engine_manufacturer_Ferrari              11235 non-null  bool
#  19  engine_manufacturer_Ford                 11235 non-null  bool
#  20  engine_manufacturer_Hart                 11235 non-null  bool
#  21  engine_manufacturer_Honda                11235 non-null  bool
#  22  engine_manufacturer_Mecachrome           11235 non-null  bool
#  23  engine_manufacturer_Mercedes             11235 non-null  bool
#  24  engine_manufacturer_Mugen-Honda          11235 non-null  bool
#  25  engine_manufacturer_Petronas             11235 non-null  bool
#  26  engine_manufacturer_Peugeot              11235 non-null  bool
#  27  engine_manufacturer_Playlife             11235 non-null  bool
#  28  engine_manufacturer_Red Bull             11235 non-null  bool
#  29  engine_manufacturer_Renault              11235 non-null  bool
#  30  engine_manufacturer_Supertec             11235 non-null  bool
#  31  engine_manufacturer_Toro Rosso           11235 non-null  bool
#  32  engine_manufacturer_Toyota               11235 non-null  bool
#  33  engine_manufacturer_Yamaha               11235 non-null  bool
#  34  constructor_nationality_American         11235 non-null  bool
#  35  constructor_nationality_Austrian         11235 non-null  bool
#  36  constructor_nationality_British          11235 non-null  bool
#  37  constructor_nationality_Dutch            11235 non-null  bool
#  38  constructor_nationality_French           11235 non-null  bool
#  39  constructor_nationality_German           11235 non-null  bool
#  40  constructor_nationality_Indian           11235 non-null  bool
#  41  constructor_nationality_Irish            11235 non-null  bool
#  42  constructor_nationality_Italian          11235 non-null  bool
#  43  constructor_nationality_Japanese         11235 non-null  bool
#  44  constructor_nationality_Malaysian        11235 non-null  bool
#  45  constructor_nationality_Russian          11235 non-null  bool
#  46  constructor_nationality_Spanish          11235 non-null  bool
#  47  constructor_nationality_Swiss            11235 non-null  bool
#  48  Nationality_American                     11235 non-null  bool
#  49  Nationality_Argentine                    11235 non-null  bool
#  50  Nationality_Australian                   11235 non-null  bool
#  51  Nationality_Austrian                     11235 non-null  bool
#  52  Nationality_Belgian                      11235 non-null  bool
#  53  Nationality_Brazilian                    11235 non-null  bool
#  54  Nationality_British                      11235 non-null  bool
#  55  Nationality_Canadian                     11235 non-null  bool
#  56  Nationality_Chinese                      11235 non-null  bool
#  57  Nationality_Colombian                    11235 non-null  bool
#  58  Nationality_Czech                        11235 non-null  bool
#  59  Nationality_Danish                       11235 non-null  bool
#  60  Nationality_Dutch                        11235 non-null  bool
#  61  Nationality_Finnish                      11235 non-null  bool
#  62  Nationality_French                       11235 non-null  bool
#  63  Nationality_German                       11235 non-null  bool
#  64  Nationality_Hungarian                    11235 non-null  bool
#  65  Nationality_Indian                       11235 non-null  bool
#  66  Nationality_Indonesian                   11235 non-null  bool
#  67  Nationality_Irish                        11235 non-null  bool
#  68  Nationality_Italian                      11235 non-null  bool
#  69  Nationality_Japanese                     11235 non-null  bool
#  70  Nationality_Malaysian                    11235 non-null  bool
#  71  Nationality_Mexican                      11235 non-null  bool
#  72  Nationality_Monegasque                   11235 non-null  bool
#  73  Nationality_New Zealander                11235 non-null  bool
#  74  Nationality_Polish                       11235 non-null  bool
#  75  Nationality_Portuguese                   11235 non-null  bool
#  76  Nationality_Russian                      11235 non-null  bool
#  77  Nationality_Spanish                      11235 non-null  bool
#  78  Nationality_Swedish                      11235 non-null  bool
#  79  Nationality_Swiss                        11235 non-null  bool
#  80  Nationality_Thai                         11235 non-null  bool
#  81  Nationality_Venezuelan                   11235 non-null  bool
# dtypes: bool(69), float64(4), int64(8), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# ### Reviewing fastest_lap_from_last_race - not sure why this is an object

# %%
print(df_with_dummies['fastest_lap_from_last_race'].unique())
# Out:
# [nan '83003' 'Not Found' '82005' '81000' '83002' '83007' '84004' '84001'
#  '83004' '86003' '81009' '83000' '84007' '89008' '88008' '86005' '83008'
#  '87008' '87004' '86000' '88005' '91003' '92001' '91005' '92009' '94003'
#  '94008' '95001' '96008' '93001' '94006' '94001' '94000' '101007' '95003'
#  '94004' '96009' '95004' '90000' '90007' '90006' '92008' '91009' '94005'
#  '93005' '90001' '106007' '97002' '100008' '91001' '98005' '98009'
#  '120007' '93004' '96001' '107001' '96005' '105006' '85004' '85005'
#  '86007' '86008' '87003' '86002' '86009' '89000' '85008' '87005' '87000'
#  '86004' '92004' '88002' '90009' '88009' '87007' '85006' '88004' '87009'
#  '88006' '90002' '90004' '90005' '92005' '91008' '101009' '93000' '91002'
#  '91006' '93009' '89002' '92002' '92007' '98001' '96006' '81006' '81002'
#  '82008' '81004' '83009' '81005' '80002' '83001' '90008' '91004' '93006'
#  '104000' '90003' '93002' '98007' '95000' '95006' '96004' '111008'
#  '114000' '110007' '111007' '110009' '111004' '112000' '111006' '113009'
#  '111009' '109008' '113008' '116000' '122002' '114005' '119008' '114003'
#  '82002' '81001' '82003' '84006' '84003' '83006' '84000' '81003' '82000'
#  '87006' '86001' '113004' '117009' '115005' '118009' '116003' '116006'
#  '117000' '118003' '118004' '114006' '117004' '117002' '117005' '117007'
#  '123006' '123005' '119003' '124002' '120001' '87001' '89009' '89007'
#  '89004' '92006' '86006' '85003' '84005' '88000' '85001' '87002' '101006'
#  '82007' '82009' '84002' '97004' '85000' '83005' '99003' '98008' '79000'
#  '77007' '76004' '78009' '78008' '78003' '77009' '80003' '80001' '78002'
#  '80006' '80009' '80008' '82001' '80000' '104003' '103001' '103002'
#  '104004' '112002' '106008' '104002' '111003' '103005' '107000' '103000'
#  '103004' '106006' '116004' '110003' '107006' '110000' '127009' '78000'
#  '79001' '81008' '80005' '79005' '85002' '94007' '95005' '116005' '99008'
#  '95008' '97000' '97006' '96002' '82004' '91007' '91000' '93007' '85007'
#  '89005' '116007' '113005' '93003' '118005' '111000' '109007' '120006'
#  '106005' '109000' '108007' '109005' '109001' '115001' '112007' '108003'
#  '84009' '85009' '79009' '79006' '80004' '79002' '79004' '81007' '79007'
#  '89003' '108009' '107005' '109006' '110008' '109002' '110006' '108006'
#  '82006' '100004' '115007' '116008' '114009' '113001' '116009' '117001'
#  '119007' '118008' '88007' '89001' '84008' '106004' '106009' '108005'
#  '105003' '105008' '106003' '109004' '109003' '93008' '95009' '96000'
#  '94002' '92000' '78004' '79008' '79003' '80007' '88001' '97007' '131002'
#  '115002' '114002' '113003' '115008' '120000' '116001' '115003' '138006'
#  '115000' '78001' '142002' '194007' '196003' '106001' '110002' '107007'
#  '108002' '119002' '113007' '123008' '115004' '139002' '114001' '114007'
#  '137008' '119004' '89006' '72002' '72008' '73007' '73006' '73008' '73009'
#  '72004' '74004' '73000' '73001' '73005' '74009' '74007' '99009' '100002'
#  '100009' '100003' '100007' '103007' '102006' '101004' '99004' '100000'
#  '104009' '104001' '96007' '95007' '88003' '94009' '78005' '97009' '97005'
#  '97003' '105007' '104008' '102003' '98002' '98004' '98000' '100001'
#  '101001' '75004' '74001' '75006' '75008' '74000' '76006' '76008' '76007'
#  '122001' '77008' '107009' '107003' '108004' '108008' '109009' '107008'
#  '131000' '128008' '126003' '124008' '127006' '128006' '126006' '128004'
#  '140000' '133002' '132007' '131003' '130005' '132004' '132003' '102004'
#  '103009' '105009' '97001' '95002' '123000' '76002' '73002' '75009'
#  '74006' '73003' '108001' '111005' '118002' '119009' '118006' '102001'
#  '101003' '102008' '102000' '101000' '101008' '103006' '104007' '103003'
#  '75002' '78007' '77000' '76000' '72009' '77006' '74002' '107002' '106002'
#  '114008' '117003' '127002' '117008' '147001' '75007' '75003' '75001'
#  '76005' '76001' '76003' '101002' '103008' '100005' '102007' '99001'
#  '102002' '102005' '0' '104006' '106000' '112005' '77005' '77001' '78006'
#  '71008' '71001' '71000' '71004' '72007' '72001' '77002' '77004' '77003'
#  '112006' '111001' '112008' '112004' '120008' '116002' '76009' '75005'
#  '99005' '99006' '99002' '101005' '100006' '102009' '71002' '70009'
#  '69003' '72006' '71005' '71003' '75000' '111002' '74003' '74008' '98003'
#  '97008' '96003' '131004' '70006' '70002' '70001' '70004' '68003' '69009'
#  '70005' '70008' '71007' '69000' '72000' '72005' '92003' '71009' '110005'
#  '98006' '73004' '74005' '112003' '113006' '118007' '122006' '121001'
#  '144005' '128007' '125007' '99000' '99007' '105004' '171009' '202003'
#  '146008' '108000' '123007' '112001' '160006' '120003' '113000' '107004'
#  '124003' '120005' '120002' '119005' '120009' '125000' '129001' '129004'
#  '127001' '123009' '147003' '113002' '134003' '134005' '110001' '112009'
#  '140002' '118000' '161004' '104005' '105001' '130004' '110004' '118001'
#  '115006' '114004' '119001' '120004' '129000' '128005' '176002' '105005'
#  '115009' '105000' '72003' '141008' '152009' '70000' '69008' '68004'
#  '68005' '70003' '169008' '117006' '135003' '105002' '69007' '69001'
#  '68001' '67005' '67004' '69002' '68008' '69006' '134006' '126005' '67001'
#  '68006' '68002' '67002' '68000' '69005' '68007' '70007' '71006' '68009'
#  '69004' '1123002' '2909008' '67003' '67000']

# %% [markdown]
# Looking at this, they should be an integer as they are recorded in Millisecond. I will turn this column into an integret

# %%
# Replace 'Not Found' with NaN
df_with_dummies['fastest_lap_from_last_race'] = df_with_dummies['fastest_lap_from_last_race'].replace('Not Found', np.nan)

# Convert the column to Pandas nullable integer type
df_with_dummies['fastest_lap_from_last_race'] = df_with_dummies['fastest_lap_from_last_race'].astype('Int64')

# %%
df_with_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11235 entries, 0 to 11234
# Data columns (total 82 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   race_index                               11235 non-null  int64
#  1   year                                     11235 non-null  int64
#  2   F2_champion                              11235 non-null  int64
#  3   Former_F1_World_Champion                 11235 non-null  int64
#  4   home_race                                11235 non-null  int64
#  5   constructorId                            11235 non-null  int64
#  6   starting_grid_position                   11235 non-null  int64
#  7   points_in_previous_race                  10921 non-null  float64
#  8   fastest_lap_from_last_race               8902 non-null   Int64
#  9   laps_in_previous_race                    10921 non-null  float64
#  10  race_win                                 11235 non-null  int64
#  11  constructorId_points_at_stage_of_season  11235 non-null  float64
#  12  driver_points_at_stage_of_season         11235 non-null  float64
#  13  engine_manufacturer_Acer                 11235 non-null  bool
#  14  engine_manufacturer_Arrows               11235 non-null  bool
#  15  engine_manufacturer_Asiatech             11235 non-null  bool
#  16  engine_manufacturer_BMW                  11235 non-null  bool
#  17  engine_manufacturer_Cosworth             11235 non-null  bool
#  18  engine_manufacturer_Ferrari              11235 non-null  bool
#  19  engine_manufacturer_Ford                 11235 non-null  bool
#  20  engine_manufacturer_Hart                 11235 non-null  bool
#  21  engine_manufacturer_Honda                11235 non-null  bool
#  22  engine_manufacturer_Mecachrome           11235 non-null  bool
#  23  engine_manufacturer_Mercedes             11235 non-null  bool
#  24  engine_manufacturer_Mugen-Honda          11235 non-null  bool
#  25  engine_manufacturer_Petronas             11235 non-null  bool
#  26  engine_manufacturer_Peugeot              11235 non-null  bool
#  27  engine_manufacturer_Playlife             11235 non-null  bool
#  28  engine_manufacturer_Red Bull             11235 non-null  bool
#  29  engine_manufacturer_Renault              11235 non-null  bool
#  30  engine_manufacturer_Supertec             11235 non-null  bool
#  31  engine_manufacturer_Toro Rosso           11235 non-null  bool
#  32  engine_manufacturer_Toyota               11235 non-null  bool
#  33  engine_manufacturer_Yamaha               11235 non-null  bool
#  34  constructor_nationality_American         11235 non-null  bool
#  35  constructor_nationality_Austrian         11235 non-null  bool
#  36  constructor_nationality_British          11235 non-null  bool
#  37  constructor_nationality_Dutch            11235 non-null  bool
#  38  constructor_nationality_French           11235 non-null  bool
#  39  constructor_nationality_German           11235 non-null  bool
#  40  constructor_nationality_Indian           11235 non-null  bool
#  41  constructor_nationality_Irish            11235 non-null  bool
#  42  constructor_nationality_Italian          11235 non-null  bool
#  43  constructor_nationality_Japanese         11235 non-null  bool
#  44  constructor_nationality_Malaysian        11235 non-null  bool
#  45  constructor_nationality_Russian          11235 non-null  bool
#  46  constructor_nationality_Spanish          11235 non-null  bool
#  47  constructor_nationality_Swiss            11235 non-null  bool
#  48  Nationality_American                     11235 non-null  bool
#  49  Nationality_Argentine                    11235 non-null  bool
#  50  Nationality_Australian                   11235 non-null  bool
#  51  Nationality_Austrian                     11235 non-null  bool
#  52  Nationality_Belgian                      11235 non-null  bool
#  53  Nationality_Brazilian                    11235 non-null  bool
#  54  Nationality_British                      11235 non-null  bool
#  55  Nationality_Canadian                     11235 non-null  bool
#  56  Nationality_Chinese                      11235 non-null  bool
#  57  Nationality_Colombian                    11235 non-null  bool
#  58  Nationality_Czech                        11235 non-null  bool
#  59  Nationality_Danish                       11235 non-null  bool
#  60  Nationality_Dutch                        11235 non-null  bool
#  61  Nationality_Finnish                      11235 non-null  bool
#  62  Nationality_French                       11235 non-null  bool
#  63  Nationality_German                       11235 non-null  bool
#  64  Nationality_Hungarian                    11235 non-null  bool
#  65  Nationality_Indian                       11235 non-null  bool
#  66  Nationality_Indonesian                   11235 non-null  bool
#  67  Nationality_Irish                        11235 non-null  bool
#  68  Nationality_Italian                      11235 non-null  bool
#  69  Nationality_Japanese                     11235 non-null  bool
#  70  Nationality_Malaysian                    11235 non-null  bool
#  71  Nationality_Mexican                      11235 non-null  bool
#  72  Nationality_Monegasque                   11235 non-null  bool
#  73  Nationality_New Zealander                11235 non-null  bool
#  74  Nationality_Polish                       11235 non-null  bool
#  75  Nationality_Portuguese                   11235 non-null  bool
#  76  Nationality_Russian                      11235 non-null  bool
#  77  Nationality_Spanish                      11235 non-null  bool
#  78  Nationality_Swedish                      11235 non-null  bool
#  79  Nationality_Swiss                        11235 non-null  bool
#  80  Nationality_Thai                         11235 non-null  bool
#  81  Nationality_Venezuelan                   11235 non-null  bool
# dtypes: Int64(1), bool(69), float64(4), int64(8)
# memory usage: 1.9 MB

# %%
rows_with_nan = df_with_dummies[df_with_dummies['fastest_lap_from_last_race'].isna()]
print(rows_with_nan)
# Out:
#        race_index  year  F2_champion  Former_F1_World_Champion  home_race  \
# 0               1  1995            0                         0          0
# 1               1  1995            0                         0          0
# 2               1  1995            0                         1          0
# 3               1  1995            0                         0          0
# 4               1  1995            0                         0          0
# ...           ...   ...          ...                       ...        ...
# 11222         527  2023            0                         0          0
# 11224         527  2023            0                         0          0
# 11230         527  2023            1                         0          0
# 11233         527  2023            1                         0          0
# 11234         527  2023            0                         0          0
#
#        constructorId  starting_grid_position  points_in_previous_race  \
# 0                  1                       7                      NaN
# 1                  1                       9                      NaN
# 2                  3                       1                      NaN
# 3                  3                       3                      NaN
# 4                  6                       5                      NaN
# ...              ...                     ...                      ...
# 11222              9                       2                     15.0
# 11224             51                      17                      0.0
# 11230            210                       0                      0.0
# 11233            214                      12                      0.0
# 11234            214                      14                      0.0
#
#        fastest_lap_from_last_race  laps_in_previous_race  race_win  \
# 0                            <NA>                    NaN         0
# 1                            <NA>                    NaN         0
# 2                            <NA>                    NaN         0
# 3                            <NA>                    NaN         0
# 4                            <NA>                    NaN         0
# ...                           ...                    ...       ...
# 11222                        <NA>                   70.0         0
# 11224                        <NA>                   69.0         0
# 11230                        <NA>                   69.0         0
# 11233                        <NA>                    1.0         0
# 11234                        <NA>                    2.0         0
#
#        constructorId_points_at_stage_of_season  \
# 0                                          4.0
# 1                                          4.0
# 2                                          6.0
# 3                                          6.0
# 4                                          6.0
# ...                                        ...
# 11222                                    466.0
# 11224                                      9.0
# 11230                                      8.0
# 11233                                     49.0
# 11234                                     49.0
#
#        driver_points_at_stage_of_season  engine_manufacturer_Acer  \
# 0                                   3.0                     False
# 1                                   1.0                     False
# 2                                   0.0                     False
# 3                                   6.0                     False
# 4                                   4.0                     False
# ...                                 ...                       ...
# 11222                             174.0                     False
# 11224                               4.0                     False
# 11230                               6.0                     False
# 11233                              16.0                     False
# 11234                              33.0                     False
#
#        engine_manufacturer_Arrows  engine_manufacturer_Asiatech  \
# 0                           False                         False
# 1                           False                         False
# 2                           False                         False
# 3                           False                         False
# 4                           False                         False
# ...                           ...                           ...
# 11222                       False                         False
# 11224                       False                         False
# 11230                       False                         False
# 11233                       False                         False
# 11234                       False                         False
#
#        engine_manufacturer_BMW  engine_manufacturer_Cosworth  \
# 0                        False                         False
# 1                        False                         False
# 2                        False                         False
# 3                        False                         False
# 4                        False                         False
# ...                        ...                           ...
# 11222                    False                         False
# 11224                    False                         False
# 11230                    False                         False
# 11233                    False                         False
# 11234                    False                         False
#
#        engine_manufacturer_Ferrari  engine_manufacturer_Ford  \
# 0                            False                     False
# 1                            False                     False
# 2                            False                     False
# 3                            False                     False
# 4                             True                     False
# ...                            ...                       ...
# 11222                        False                     False
# 11224                         True                     False
# 11230                         True                     False
# 11233                        False                     False
# 11234                        False                     False
#
#        engine_manufacturer_Hart  engine_manufacturer_Honda  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
# ...                         ...                        ...
# 11222                     False                       True
# 11224                     False                      False
# 11230                     False                      False
# 11233                     False                      False
# 11234                     False                      False
#
#        engine_manufacturer_Mecachrome  engine_manufacturer_Mercedes  \
# 0                               False                          True
# 1                               False                          True
# 2                               False                         False
# 3                               False                         False
# 4                               False                         False
# ...                               ...                           ...
# 11222                           False                         False
# 11224                           False                         False
# 11230                           False                         False
# 11233                           False                         False
# 11234                           False                         False
#
#        engine_manufacturer_Mugen-Honda  engine_manufacturer_Petronas  \
# 0                                False                         False
# 1                                False                         False
# 2                                False                         False
# 3                                False                         False
# 4                                False                         False
# ...                                ...                           ...
# 11222                            False                         False
# 11224                            False                         False
# 11230                            False                         False
# 11233                            False                         False
# 11234                            False                         False
#
#        engine_manufacturer_Peugeot  engine_manufacturer_Playlife  \
# 0                            False                         False
# 1                            False                         False
# 2                            False                         False
# 3                            False                         False
# 4                            False                         False
# ...                            ...                           ...
# 11222                        False                         False
# 11224                        False                         False
# 11230                        False                         False
# 11233                        False                         False
# 11234                        False                         False
#
#        engine_manufacturer_Red Bull  engine_manufacturer_Renault  \
# 0                             False                        False
# 1                             False                        False
# 2                             False                         True
# 3                             False                         True
# 4                             False                        False
# ...                             ...                          ...
# 11222                         False                        False
# 11224                         False                        False
# 11230                         False                        False
# 11233                         False                         True
# 11234                         False                         True
#
#        engine_manufacturer_Supertec  engine_manufacturer_Toro Rosso  \
# 0                             False                           False
# 1                             False                           False
# 2                             False                           False
# 3                             False                           False
# 4                             False                           False
# ...                             ...                             ...
# 11222                         False                           False
# 11224                         False                           False
# 11230                         False                           False
# 11233                         False                           False
# 11234                         False                           False
#
#        engine_manufacturer_Toyota  engine_manufacturer_Yamaha  \
# 0                           False                       False
# 1                           False                       False
# 2                           False                       False
# 3                           False                       False
# 4                           False                       False
# ...                           ...                         ...
# 11222                       False                       False
# 11224                       False                       False
# 11230                       False                       False
# 11233                       False                       False
# 11234                       False                       False
#
#        constructor_nationality_American  constructor_nationality_Austrian  \
# 0                                 False                             False
# 1                                 False                             False
# 2                                 False                             False
# 3                                 False                             False
# 4                                 False                             False
# ...                                 ...                               ...
# 11222                             False                              True
# 11224                             False                             False
# 11230                              True                             False
# 11233                             False                             False
# 11234                             False                             False
#
#        constructor_nationality_British  constructor_nationality_Dutch  \
# 0                                 True                          False
# 1                                 True                          False
# 2                                 True                          False
# 3                                 True                          False
# 4                                False                          False
# ...                                ...                            ...
# 11222                            False                          False
# 11224                            False                          False
# 11230                            False                          False
# 11233                            False                          False
# 11234                            False                          False
#
#        constructor_nationality_French  constructor_nationality_German  \
# 0                               False                           False
# 1                               False                           False
# 2                               False                           False
# 3                               False                           False
# 4                               False                           False
# ...                               ...                             ...
# 11222                           False                           False
# 11224                           False                           False
# 11230                           False                           False
# 11233                            True                           False
# 11234                            True                           False
#
#        constructor_nationality_Indian  constructor_nationality_Irish  \
# 0                               False                          False
# 1                               False                          False
# 2                               False                          False
# 3                               False                          False
# 4                               False                          False
# ...                               ...                            ...
# 11222                           False                          False
# 11224                           False                          False
# 11230                           False                          False
# 11233                           False                          False
# 11234                           False                          False
#
#        constructor_nationality_Italian  constructor_nationality_Japanese  \
# 0                                False                             False
# 1                                False                             False
# 2                                False                             False
# 3                                False                             False
# 4                                 True                             False
# ...                                ...                               ...
# 11222                            False                             False
# 11224                            False                             False
# 11230                            False                             False
# 11233                            False                             False
# 11234                            False                             False
#
#        constructor_nationality_Malaysian  constructor_nationality_Russian  \
# 0                                  False                            False
# 1                                  False                            False
# 2                                  False                            False
# 3                                  False                            False
# 4                                  False                            False
# ...                                  ...                              ...
# 11222                              False                            False
# 11224                              False                            False
# 11230                              False                            False
# 11233                              False                            False
# 11234                              False                            False
#
#        constructor_nationality_Spanish  constructor_nationality_Swiss  \
# 0                                False                          False
# 1                                False                          False
# 2                                False                          False
# 3                                False                          False
# 4                                False                          False
# ...                                ...                            ...
# 11222                            False                          False
# 11224                            False                           True
# 11230                            False                          False
# 11233                            False                          False
# 11234                            False                          False
#
#        Nationality_American  Nationality_Argentine  Nationality_Australian  \
# 0                     False                  False                   False
# 1                     False                  False                   False
# 2                     False                  False                   False
# 3                     False                  False                   False
# 4                     False                  False                   False
# ...                     ...                    ...                     ...
# 11222                 False                  False                   False
# 11224                 False                  False                   False
# 11230                 False                  False                   False
# 11233                 False                  False                   False
# 11234                 False                  False                   False
#
#        Nationality_Austrian  Nationality_Belgian  Nationality_Brazilian  \
# 0                     False                False                  False
# 1                     False                False                  False
# 2                     False                False                  False
# 3                     False                False                  False
# 4                      True                False                  False
# ...                     ...                  ...                    ...
# 11222                 False                False                  False
# 11224                 False                False                  False
# 11230                 False                False                  False
# 11233                 False                False                  False
# 11234                 False                False                  False
#
#        Nationality_British  Nationality_Canadian  Nationality_Chinese  \
# 0                    False                 False                False
# 1                     True                 False                False
# 2                     True                 False                False
# 3                     True                 False                False
# 4                    False                 False                False
# ...                    ...                   ...                  ...
# 11222                False                 False                False
# 11224                False                 False                 True
# 11230                False                 False                False
# 11233                False                 False                False
# 11234                False                 False                False
#
#        Nationality_Colombian  Nationality_Czech  Nationality_Danish  \
# 0                      False              False               False
# 1                      False              False               False
# 2                      False              False               False
# 3                      False              False               False
# 4                      False              False               False
# ...                      ...                ...                 ...
# 11222                  False              False               False
# 11224                  False              False               False
# 11230                  False              False               False
# 11233                  False              False               False
# 11234                  False              False               False
#
#        Nationality_Dutch  Nationality_Finnish  Nationality_French  \
# 0                  False                 True               False
# 1                  False                False               False
# 2                  False                False               False
# 3                  False                False               False
# 4                  False                False               False
# ...                  ...                  ...                 ...
# 11222              False                False               False
# 11224              False                False               False
# 11230              False                False               False
# 11233              False                False                True
# 11234              False                False                True
#
#        Nationality_German  Nationality_Hungarian  Nationality_Indian  \
# 0                   False                  False               False
# 1                   False                  False               False
# 2                   False                  False               False
# 3                   False                  False               False
# 4                   False                  False               False
# ...                   ...                    ...                 ...
# 11222               False                  False               False
# 11224               False                  False               False
# 11230                True                  False               False
# 11233               False                  False               False
# 11234               False                  False               False
#
#        Nationality_Indonesian  Nationality_Irish  Nationality_Italian  \
# 0                       False              False                False
# 1                       False              False                False
# 2                       False              False                False
# 3                       False              False                False
# 4                       False              False                False
# ...                       ...                ...                  ...
# 11222                   False              False                False
# 11224                   False              False                False
# 11230                   False              False                False
# 11233                   False              False                False
# 11234                   False              False                False
#
#        Nationality_Japanese  Nationality_Malaysian  Nationality_Mexican  \
# 0                     False                  False                False
# 1                     False                  False                False
# 2                     False                  False                False
# 3                     False                  False                False
# 4                     False                  False                False
# ...                     ...                    ...                  ...
# 11222                 False                  False                 True
# 11224                 False                  False                False
# 11230                 False                  False                False
# 11233                 False                  False                False
# 11234                 False                  False                False
#
#        Nationality_Monegasque  Nationality_New Zealander  Nationality_Polish  \
# 0                       False                      False               False
# 1                       False                      False               False
# 2                       False                      False               False
# 3                       False                      False               False
# 4                       False                      False               False
# ...                       ...                        ...                 ...
# 11222                   False                      False               False
# 11224                   False                      False               False
# 11230                   False                      False               False
# 11233                   False                      False               False
# 11234                   False                      False               False
#
#        Nationality_Portuguese  Nationality_Russian  Nationality_Spanish  \
# 0                       False                False                False
# 1                       False                False                False
# 2                       False                False                False
# 3                       False                False                False
# 4                       False                False                False
# ...                       ...                  ...                  ...
# 11222                   False                False                False
# 11224                   False                False                False
# 11230                   False                False                False
# 11233                   False                False                False
# 11234                   False                False                False
#
#        Nationality_Swedish  Nationality_Swiss  Nationality_Thai  \
# 0                    False              False             False
# 1                    False              False             False
# 2                    False              False             False
# 3                    False              False             False
# 4                    False              False             False
# ...                    ...                ...               ...
# 11222                False              False             False
# 11224                False              False             False
# 11230                False              False             False
# 11233                False              False             False
# 11234                False              False             False
#
#        Nationality_Venezuelan
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 11222                   False
# 11224                   False
# 11230                   False
# 11233                   False
# 11234                   False
#
# [2333 rows x 82 columns]

# %%
nan_percentage = df_with_dummies['fastest_lap_from_last_race'].isna().mean() * 100
print(f'Percentage of NaN values in fastest_lap_from_last_race: {nan_percentage:.2f}%')
# Out:
# Percentage of NaN values in fastest_lap_from_last_race: 20.77%

# %% [markdown]
# There are quite a lot of missing values from column "fastest_lap_from_last_race", so I'm going to drop this for the time being and I might bring this back after running some initial models if I can decide on an imputation strategy.

# %%
df_with_dummies = df_with_dummies.drop('fastest_lap_from_last_race', axis=1)

# %% [markdown]
# # Drop remaining null values

# %%
df_with_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11235 entries, 0 to 11234
# Data columns (total 81 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   race_index                               11235 non-null  int64
#  1   year                                     11235 non-null  int64
#  2   F2_champion                              11235 non-null  int64
#  3   Former_F1_World_Champion                 11235 non-null  int64
#  4   home_race                                11235 non-null  int64
#  5   constructorId                            11235 non-null  int64
#  6   starting_grid_position                   11235 non-null  int64
#  7   points_in_previous_race                  10921 non-null  float64
#  8   laps_in_previous_race                    10921 non-null  float64
#  9   race_win                                 11235 non-null  int64
#  10  constructorId_points_at_stage_of_season  11235 non-null  float64
#  11  driver_points_at_stage_of_season         11235 non-null  float64
#  12  engine_manufacturer_Acer                 11235 non-null  bool
#  13  engine_manufacturer_Arrows               11235 non-null  bool
#  14  engine_manufacturer_Asiatech             11235 non-null  bool
#  15  engine_manufacturer_BMW                  11235 non-null  bool
#  16  engine_manufacturer_Cosworth             11235 non-null  bool
#  17  engine_manufacturer_Ferrari              11235 non-null  bool
#  18  engine_manufacturer_Ford                 11235 non-null  bool
#  19  engine_manufacturer_Hart                 11235 non-null  bool
#  20  engine_manufacturer_Honda                11235 non-null  bool
#  21  engine_manufacturer_Mecachrome           11235 non-null  bool
#  22  engine_manufacturer_Mercedes             11235 non-null  bool
#  23  engine_manufacturer_Mugen-Honda          11235 non-null  bool
#  24  engine_manufacturer_Petronas             11235 non-null  bool
#  25  engine_manufacturer_Peugeot              11235 non-null  bool
#  26  engine_manufacturer_Playlife             11235 non-null  bool
#  27  engine_manufacturer_Red Bull             11235 non-null  bool
#  28  engine_manufacturer_Renault              11235 non-null  bool
#  29  engine_manufacturer_Supertec             11235 non-null  bool
#  30  engine_manufacturer_Toro Rosso           11235 non-null  bool
#  31  engine_manufacturer_Toyota               11235 non-null  bool
#  32  engine_manufacturer_Yamaha               11235 non-null  bool
#  33  constructor_nationality_American         11235 non-null  bool
#  34  constructor_nationality_Austrian         11235 non-null  bool
#  35  constructor_nationality_British          11235 non-null  bool
#  36  constructor_nationality_Dutch            11235 non-null  bool
#  37  constructor_nationality_French           11235 non-null  bool
#  38  constructor_nationality_German           11235 non-null  bool
#  39  constructor_nationality_Indian           11235 non-null  bool
#  40  constructor_nationality_Irish            11235 non-null  bool
#  41  constructor_nationality_Italian          11235 non-null  bool
#  42  constructor_nationality_Japanese         11235 non-null  bool
#  43  constructor_nationality_Malaysian        11235 non-null  bool
#  44  constructor_nationality_Russian          11235 non-null  bool
#  45  constructor_nationality_Spanish          11235 non-null  bool
#  46  constructor_nationality_Swiss            11235 non-null  bool
#  47  Nationality_American                     11235 non-null  bool
#  48  Nationality_Argentine                    11235 non-null  bool
#  49  Nationality_Australian                   11235 non-null  bool
#  50  Nationality_Austrian                     11235 non-null  bool
#  51  Nationality_Belgian                      11235 non-null  bool
#  52  Nationality_Brazilian                    11235 non-null  bool
#  53  Nationality_British                      11235 non-null  bool
#  54  Nationality_Canadian                     11235 non-null  bool
#  55  Nationality_Chinese                      11235 non-null  bool
#  56  Nationality_Colombian                    11235 non-null  bool
#  57  Nationality_Czech                        11235 non-null  bool
#  58  Nationality_Danish                       11235 non-null  bool
#  59  Nationality_Dutch                        11235 non-null  bool
#  60  Nationality_Finnish                      11235 non-null  bool
#  61  Nationality_French                       11235 non-null  bool
#  62  Nationality_German                       11235 non-null  bool
#  63  Nationality_Hungarian                    11235 non-null  bool
#  64  Nationality_Indian                       11235 non-null  bool
#  65  Nationality_Indonesian                   11235 non-null  bool
#  66  Nationality_Irish                        11235 non-null  bool
#  67  Nationality_Italian                      11235 non-null  bool
#  68  Nationality_Japanese                     11235 non-null  bool
#  69  Nationality_Malaysian                    11235 non-null  bool
#  70  Nationality_Mexican                      11235 non-null  bool
#  71  Nationality_Monegasque                   11235 non-null  bool
#  72  Nationality_New Zealander                11235 non-null  bool
#  73  Nationality_Polish                       11235 non-null  bool
#  74  Nationality_Portuguese                   11235 non-null  bool
#  75  Nationality_Russian                      11235 non-null  bool
#  76  Nationality_Spanish                      11235 non-null  bool
#  77  Nationality_Swedish                      11235 non-null  bool
#  78  Nationality_Swiss                        11235 non-null  bool
#  79  Nationality_Thai                         11235 non-null  bool
#  80  Nationality_Venezuelan                   11235 non-null  bool
# dtypes: bool(69), float64(4), int64(8)
# memory usage: 1.8 MB

# %%
df_with_dummies = df_with_dummies.dropna()

# %%
df_with_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10921 entries, 26 to 11234
# Data columns (total 81 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   race_index                               10921 non-null  int64
#  1   year                                     10921 non-null  int64
#  2   F2_champion                              10921 non-null  int64
#  3   Former_F1_World_Champion                 10921 non-null  int64
#  4   home_race                                10921 non-null  int64
#  5   constructorId                            10921 non-null  int64
#  6   starting_grid_position                   10921 non-null  int64
#  7   points_in_previous_race                  10921 non-null  float64
#  8   laps_in_previous_race                    10921 non-null  float64
#  9   race_win                                 10921 non-null  int64
#  10  constructorId_points_at_stage_of_season  10921 non-null  float64
#  11  driver_points_at_stage_of_season         10921 non-null  float64
#  12  engine_manufacturer_Acer                 10921 non-null  bool
#  13  engine_manufacturer_Arrows               10921 non-null  bool
#  14  engine_manufacturer_Asiatech             10921 non-null  bool
#  15  engine_manufacturer_BMW                  10921 non-null  bool
#  16  engine_manufacturer_Cosworth             10921 non-null  bool
#  17  engine_manufacturer_Ferrari              10921 non-null  bool
#  18  engine_manufacturer_Ford                 10921 non-null  bool
#  19  engine_manufacturer_Hart                 10921 non-null  bool
#  20  engine_manufacturer_Honda                10921 non-null  bool
#  21  engine_manufacturer_Mecachrome           10921 non-null  bool
#  22  engine_manufacturer_Mercedes             10921 non-null  bool
#  23  engine_manufacturer_Mugen-Honda          10921 non-null  bool
#  24  engine_manufacturer_Petronas             10921 non-null  bool
#  25  engine_manufacturer_Peugeot              10921 non-null  bool
#  26  engine_manufacturer_Playlife             10921 non-null  bool
#  27  engine_manufacturer_Red Bull             10921 non-null  bool
#  28  engine_manufacturer_Renault              10921 non-null  bool
#  29  engine_manufacturer_Supertec             10921 non-null  bool
#  30  engine_manufacturer_Toro Rosso           10921 non-null  bool
#  31  engine_manufacturer_Toyota               10921 non-null  bool
#  32  engine_manufacturer_Yamaha               10921 non-null  bool
#  33  constructor_nationality_American         10921 non-null  bool
#  34  constructor_nationality_Austrian         10921 non-null  bool
#  35  constructor_nationality_British          10921 non-null  bool
#  36  constructor_nationality_Dutch            10921 non-null  bool
#  37  constructor_nationality_French           10921 non-null  bool
#  38  constructor_nationality_German           10921 non-null  bool
#  39  constructor_nationality_Indian           10921 non-null  bool
#  40  constructor_nationality_Irish            10921 non-null  bool
#  41  constructor_nationality_Italian          10921 non-null  bool
#  42  constructor_nationality_Japanese         10921 non-null  bool
#  43  constructor_nationality_Malaysian        10921 non-null  bool
#  44  constructor_nationality_Russian          10921 non-null  bool
#  45  constructor_nationality_Spanish          10921 non-null  bool
#  46  constructor_nationality_Swiss            10921 non-null  bool
#  47  Nationality_American                     10921 non-null  bool
#  48  Nationality_Argentine                    10921 non-null  bool
#  49  Nationality_Australian                   10921 non-null  bool
#  50  Nationality_Austrian                     10921 non-null  bool
#  51  Nationality_Belgian                      10921 non-null  bool
#  52  Nationality_Brazilian                    10921 non-null  bool
#  53  Nationality_British                      10921 non-null  bool
#  54  Nationality_Canadian                     10921 non-null  bool
#  55  Nationality_Chinese                      10921 non-null  bool
#  56  Nationality_Colombian                    10921 non-null  bool
#  57  Nationality_Czech                        10921 non-null  bool
#  58  Nationality_Danish                       10921 non-null  bool
#  59  Nationality_Dutch                        10921 non-null  bool
#  60  Nationality_Finnish                      10921 non-null  bool
#  61  Nationality_French                       10921 non-null  bool
#  62  Nationality_German                       10921 non-null  bool
#  63  Nationality_Hungarian                    10921 non-null  bool
#  64  Nationality_Indian                       10921 non-null  bool
#  65  Nationality_Indonesian                   10921 non-null  bool
#  66  Nationality_Irish                        10921 non-null  bool
#  67  Nationality_Italian                      10921 non-null  bool
#  68  Nationality_Japanese                     10921 non-null  bool
#  69  Nationality_Malaysian                    10921 non-null  bool
#  70  Nationality_Mexican                      10921 non-null  bool
#  71  Nationality_Monegasque                   10921 non-null  bool
#  72  Nationality_New Zealander                10921 non-null  bool
#  73  Nationality_Polish                       10921 non-null  bool
#  74  Nationality_Portuguese                   10921 non-null  bool
#  75  Nationality_Russian                      10921 non-null  bool
#  76  Nationality_Spanish                      10921 non-null  bool
#  77  Nationality_Swedish                      10921 non-null  bool
#  78  Nationality_Swiss                        10921 non-null  bool
#  79  Nationality_Thai                         10921 non-null  bool
#  80  Nationality_Venezuelan                   10921 non-null  bool
# dtypes: bool(69), float64(4), int64(8)
# memory usage: 1.8 MB

# %%
df_with_dummies.to_csv('model_data.csv', index=False)
